# %% [markdown]
# <a href="https://colab.research.google.com/github/galua2001/colab/blob/main/calcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
t=Symbol('t')
x=symbols('x')
n=symbols('n')
y, z =symbols('y z')

# %%
f=x**2+y
f.subs(x,4)
# Out:
# y + 16

# %%
sin(x)
asin(x)
exp(x)
log(x)# e를 베이스로 함
log(x,5)# 5를 베이스로 함
# Out:
# log(x)/log(5)

# %%
x**Rational(3,2)
# Out:
# x**(3/2)

# %%
Limit(sin(x/2 + sin(x)),x,pi, dir='-')
# Out:
# Limit(sin(x/2 + sin(x)), x, pi, dir='-')

# %%
limit(sin(x/2 + sin(x)), x, pi, dir='+')
# Out:
# 1

# %%
Limit(sin(x/2 + sin(x)),x,pi, dir='-')
# Out:
# Limit(sin(x/2 + sin(x)), x, pi, dir='-')

# %%
Limit((cos(x)-1)/x, x, oo).doit()
# Out:
# 0

# %%
Limit((cos(x)-1)/x, x, oo)
# Out:
# Limit((cos(x) - 1)/x, x, oo, dir='-')

# %%
Derivative(((1+sin(x))/(1-cos(x)))**2)
# Out:
# Derivative((sin(x) + 1)**2/(1 - cos(x))**2, x)

# %%
Derivative(((1+sin(x))/(1-cos(x)))**2).doit()
# Out:
# 2*(sin(x) + 1)*cos(x)/(1 - cos(x))**2 - 2*(sin(x) + 1)**2*sin(x)/(1 - cos(x))**3

# %%
diff(((1+sin(x))/(1-cos(x)))**2)
# Out:
# 2*(sin(x) + 1)*cos(x)/(1 - cos(x))**2 - 2*(sin(x) + 1)**2*sin(x)/(1 - cos(x))**3

# %%
Derivative(((1+sin(y))/(1-cos(x)))**2,x)
# Out:
# Derivative((sin(y) + 1)**2/(1 - cos(x))**2, x)

# %%
diff(log(x,5)**(x/2))
# Out:
# (log(x)/log(5))**(x/2)*(log(log(x)/log(5))/2 + 1/(2*log(x)))

# %%
diff(x**x,x)
# Out:
# x**x*(log(x) + 1)

# %%
f,g=symbols('f g', cls=Function)
g=g(x)
f=f(x+g)
diff(f,x)
# Out:
# (Derivative(g(x), x) + 1)*Subs(Derivative(f(_xi_1), _xi_1), _xi_1, x + g(x))

# %%
Integral(csc(x)*cot(x), x)
# Out:
# Integral(cot(x)*csc(x), x)

# %%
integrate(csc(x)*cot(x),x)
# Out:
# -1/sin(x)

# %%
integrate((2*x-1)*cos(sqrt(3*(2*x-1)**2+6))/sqrt(3*(2*x-1)**2+6),x)
# Out:
# sin(sqrt(3*(2*x - 1)**2 + 6))/6

# %%
integrate(x**10*exp(x),(x,1,t))
# Out:
# (t**10 - 10*t**9 + 90*t**8 - 720*t**7 + 5040*t**6 - 30240*t**5 + 151200*t**4 - 604800*t**3 + 1814400*t**2 - 3628800*t + 3628800)*exp(t) - 1334961*E

# %%
Integral(16*atan(x)/(1+x**2),(x,0,oo))
# Out:
# Integral(16*atan(x)/(x**2 + 1), (x, 0, oo))

# %%
integrate(2/(1-x**2)**Rational(1,2) -1/x**(1/4),x)
# Out:
# -1.33333333333333*x**0.75 + 2*asin(x)

# %%
integrate(exp(x)/sqrt(exp(2*x)+9), (x,0,log(4)))
# Out:
# -asinh(1/3) + asinh(4/3)

# %%
integral=integrate(8*x+csc(x)**2,x)
c=-integral.subs(x, pi/2)-17
y= integral+c
y
# Out:
# 4*x**2 - 17 - pi**2 - cos(x)/sin(x)

# %%
y.subs(x, pi/2)
# Out:
# -17

# %%
integrate(exp(x)/(exp(2*x)+9)**Rational(1,2),(x,0,log(4)))
# Out:
# -asinh(1/3) + asinh(4/3)

# %%
Sum(6/4**n, (n,0,oo)).doit()
# Out:
# 8

# %%
Sum(6/4**n, (n,0,oo)).doit()
# Out:
# 8

# %%
Sum(atan(n)/n**Rational(11,10),(n,1,oo)).n()
# Out:
# 15.3028821020457

# %%
Sum(atan(n)/n**Rational(11,10),(n,1,oo)).n()
# Out:
# 15.3028821020457

# %%
Sum(atan(n)/n**Rational(11,10),(n,1,oo)).doit()
# Out:
# Sum(atan(n)/n**(11/10), (n, 1, oo))

# %%
Sum((1+cos(n))/n**2, (n,1,oo)).n()
# Out:
# 1.969

# %%
Sum((-1)**n,(n,1,oo))
# Out:
# Sum((-1)**n, (n, 1, oo))

# %%
fx=x**2
plot(fx,xlim=(-5,5),ylim=(0,20))

# %%
plot(fx, x**3, 3**x)

# %%
plot_parametric((-3*cos(x),2*sin(x)),(x,-5,5))

# %%
plot_parametric((sin(x),x),(x,-5,5))

# %%
plot_parametric(t-sin(t), 1-cos(t),(t,0,2*pi))

# %%
from sympy.plotting import plot3d
x,y=symbols('x y')
plot3d(x**2+y**2,(x,-5,5),(y,-5,5))

# %%
plot_implicit(Eq(x**2+36*y**2+1*x+36*y-44-x*y, 0), (x,-10,10))

# %%
integrate((e^2*x)-e^x,(x,0,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a3579172165c> in <cell line: 0>()
# ----> 1 integrate((e^2*x)-e^x,(x,0,1))
#       2
#       3
#
# NameError: name 'e' is not defined

# %%
from sympy import integrate, symbols, E

x = symbols('x')
integrate((E**2 * x) - E**x, (x, 0, 1))
# Out:
# -E + 1 + exp(2)/2

# %%
from sympy import *
t=Symbol('t')
x=symbols('x')
n=symbols('n')
y, z =symbols('y z')

# %%
integrate(sin(x**2))
# Out:
# 3*sqrt(2)*sqrt(pi)*fresnels(sqrt(2)*x/sqrt(pi))*gamma(3/4)/(8*gamma(7/4))

# %%
from sympy import integrate, symbols, E
integrate(cos(E**x))
# Out:
# Ci(exp(x))

# %%
from sympy import integrate, symbols, E

x = symbols('x')
integrate((E**x/x))
# Out:
# Ei(x)

# %%
integrate(sin(x)/x)
# Out:
# Si(x)

# %%
integrate((2*x**2-x+4)/(x**3+4*x))
# Out:
# log(x) + log(x**2 + 4)/2 - atan(x/2)/2

# %%
integrate((1-3*x+2*x**2-x**3)/(x*(x**2+1)**2))
# Out:
# -(2*x + 1)/(2*x**2 + 2) + log(x) - log(x**2 + 1)/2 - 2*atan(x)

# %%
from sympy import integrate, symbols, E

x = symbols('x')
integrate((E**x/x))
integrate(E**x**2)
# Out:
# sqrt(pi)*erfi(x)/2

# %%
integrate(1/(sin(x)+cos(x)))
# Out:
# sqrt(2)*log(tan(x/2) - 1 + sqrt(2))/2 - sqrt(2)*log(tan(x/2) - sqrt(2) - 1)/2
